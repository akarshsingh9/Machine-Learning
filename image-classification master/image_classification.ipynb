# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 15
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 15:
# Image - Min Value: 8 Max Value: 236
# Image - Shape: (32, 32, 3)
# Label - Label Id: 9 Name: truck

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # Implement Function
    mx = x.max()
    g = np.vectorize(lambda x: x / mx)
    return g(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    y = np.zeros((len(x), 10))
    rows = range(len(x))
    cols = list(x)
    y[rows, cols] = 1
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # Implement Function
    shape = [None]
    shape.extend(image_shape)
    return tf.placeholder(tf.float32, shape=shape, name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # Implement Function
    return tf.placeholder(tf.float32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # Implement Function
    return tf.placeholder(tf.float32, shape=(None), name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
from math import sqrt

def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # First the Weights and Biases
    w_shape = [conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs]
    stddev = sqrt(2/(conv_ksize[0] * conv_ksize[1] * x_tensor.get_shape().as_list()[3]))
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))
    biases = tf.Variable(tf.zeros([conv_num_outputs]))
    # Convolution
    convolution = tf.nn.conv2d(x_tensor, weights, [1,conv_strides[0],conv_strides[1],1], padding="SAME")
    # Add ReLU and bias
    relu = tf.nn.relu(tf.add(convolution,biases))
    # Max pooling
    k_size = [1, pool_ksize[0], pool_ksize[1],1]
    m_strides = [1, pool_strides[0], pool_strides[1],1]
    max_pool = tf.nn.max_pool(relu, ksize=k_size, strides=m_strides, padding="SAME")

    return max_pool
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # Implement Function
    shape = x_tensor.get_shape().as_list()[1:]
    dim_flatt = shape[0]*shape[1]*shape[2]
    
    flatx = tf.reshape(x_tensor, [-1, dim_flatt])
    return flatx


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Weights and biases
    w_shape = [x_tensor.get_shape().as_list()[1], num_outputs]
    stddev = sqrt(2/x_tensor.get_shape().as_list()[1])
    
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), biases))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Weights and biases
    w_shape = [x_tensor.get_shape().as_list()[1], num_outputs]
    stddev = sqrt(2/x_tensor.get_shape().as_list()[1])
    
    weights = tf.Variable(tf.truncated_normal(w_shape, stddev=stddev))

    
    biases = tf.Variable(tf.zeros([num_outputs]))
    
    return tf.add(tf.matmul(x_tensor, weights), biases)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_dropout_prob = keep_prob / 2
    conv1 = conv2d_maxpool(x, 48, (3, 3), (1, 1), (2, 2), (2, 2))
    conv2 = conv2d_maxpool(conv1, 96, (3, 3), (1, 1), (2, 2), (2, 2))
    conv3 = conv2d_maxpool(conv2, 192, (3, 3), (1, 1), (2, 2), (2, 2))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv3)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fconn = fully_conn(flat, 1024) 
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    fconn = fully_conn(fconn_w_dropout, 512)
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    fconn = fully_conn(fconn_w_dropout, 256)
    fconn_w_dropout = tf.nn.dropout(fconn, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    result = output(fconn_w_dropout, 10)
    
    # TODO: return output
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.})
    valid_acc = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    
    print('Epoch Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                loss,
                valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Epoch Loss:     2.1907 Validation Accuracy: 0.213200
# Epoch  2, CIFAR-10 Batch 1:  Epoch Loss:     1.8997 Validation Accuracy: 0.343000
# Epoch  3, CIFAR-10 Batch 1:  Epoch Loss:     1.7086 Validation Accuracy: 0.434000
# Epoch  4, CIFAR-10 Batch 1:  Epoch Loss:     1.3657 Validation Accuracy: 0.464800
# Epoch  5, CIFAR-10 Batch 1:  Epoch Loss:     1.0477 Validation Accuracy: 0.489600
# Epoch  6, CIFAR-10 Batch 1:  Epoch Loss:     0.8437 Validation Accuracy: 0.504600
# Epoch  7, CIFAR-10 Batch 1:  Epoch Loss:     0.6494 Validation Accuracy: 0.549400
# Epoch  8, CIFAR-10 Batch 1:  Epoch Loss:     0.4941 Validation Accuracy: 0.562200
# Epoch  9, CIFAR-10 Batch 1:  Epoch Loss:     0.4116 Validation Accuracy: 0.568800
# Epoch 10, CIFAR-10 Batch 1:  Epoch Loss:     0.3047 Validation Accuracy: 0.563000
# Epoch 11, CIFAR-10 Batch 1:  Epoch Loss:     0.2169 Validation Accuracy: 0.606400
# Epoch 12, CIFAR-10 Batch 1:  Epoch Loss:     0.1194 Validation Accuracy: 0.594400
# Epoch 13, CIFAR-10 Batch 1:  Epoch Loss:     0.0898 Validation Accuracy: 0.590600
# Epoch 14, CIFAR-10 Batch 1:  Epoch Loss:     0.1020 Validation Accuracy: 0.600200
# Epoch 15, CIFAR-10 Batch 1:  Epoch Loss:     0.0627 Validation Accuracy: 0.600400
# Epoch 16, CIFAR-10 Batch 1:  Epoch Loss:     0.0291 Validation Accuracy: 0.596200
# Epoch 17, CIFAR-10 Batch 1:  Epoch Loss:     0.0144 Validation Accuracy: 0.596000
# Epoch 18, CIFAR-10 Batch 1:  Epoch Loss:     0.0149 Validation Accuracy: 0.600600
# Epoch 19, CIFAR-10 Batch 1:  Epoch Loss:     0.0087 Validation Accuracy: 0.605400
# Epoch 20, CIFAR-10 Batch 1:  Epoch Loss:     0.0100 Validation Accuracy: 0.622000
# Epoch 21, CIFAR-10 Batch 1:  Epoch Loss:     0.0123 Validation Accuracy: 0.604200
# Epoch 22, CIFAR-10 Batch 1:  Epoch Loss:     0.0059 Validation Accuracy: 0.599800
# Epoch 23, CIFAR-10 Batch 1:  Epoch Loss:     0.0050 Validation Accuracy: 0.608400
# Epoch 24, CIFAR-10 Batch 1:  Epoch Loss:     0.0041 Validation Accuracy: 0.606800
# Epoch 25, CIFAR-10 Batch 1:  Epoch Loss:     0.0014 Validation Accuracy: 0.615800
# Epoch 26, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.608600
# Epoch 27, CIFAR-10 Batch 1:  Epoch Loss:     0.0009 Validation Accuracy: 0.628000
# Epoch 28, CIFAR-10 Batch 1:  Epoch Loss:     0.0011 Validation Accuracy: 0.611400
# Epoch 29, CIFAR-10 Batch 1:  Epoch Loss:     0.0017 Validation Accuracy: 0.609400
# Epoch 30, CIFAR-10 Batch 1:  Epoch Loss:     0.0030 Validation Accuracy: 0.617000
# Epoch 31, CIFAR-10 Batch 1:  Epoch Loss:     0.0007 Validation Accuracy: 0.610000
# Epoch 32, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.609400
# Epoch 33, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.620000
# Epoch 34, CIFAR-10 Batch 1:  Epoch Loss:     0.0005 Validation Accuracy: 0.618000
# Epoch 35, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.616400
# Epoch 36, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.622000
# Epoch 37, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.627000
# Epoch 38, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.628800
# Epoch 39, CIFAR-10 Batch 1:  Epoch Loss:     0.0004 Validation Accuracy: 0.633400
# Epoch 40, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.621200
# Epoch 41, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.610600
# Epoch 42, CIFAR-10 Batch 1:  Epoch Loss:     0.0012 Validation Accuracy: 0.607000
# Epoch 43, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.621600
# Epoch 44, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.620800
# Epoch 45, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.619200
# Epoch 46, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.618800
# Epoch 47, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.622200
# Epoch 48, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.627600
# Epoch 49, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.628600
# Epoch 50, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.624200
# Epoch 51, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.635200
# Epoch 52, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.634600
# Epoch 53, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.630200
# Epoch 54, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.633400
# Epoch 55, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.637400
# Epoch 56, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.632600
# Epoch 57, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.620000
# Epoch 58, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.617200
# Epoch 59, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.631400
# Epoch 60, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.618600
# Epoch 61, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.625800
# Epoch 62, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.625000
# Epoch 63, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.627400
# Epoch 64, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.626600
# Epoch 65, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.618400
# Epoch 66, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.624000
# Epoch 67, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.634600
# Epoch 68, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.630000
# Epoch 69, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.629000
# Epoch 70, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.634000
# Epoch 71, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.630200
# Epoch 72, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.630400
# Epoch 73, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.628800
# Epoch 74, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.623400
# Epoch 75, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.632200
# Epoch 76, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.621200
# Epoch 77, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.638800
# Epoch 78, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.631400
# Epoch 79, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.626000
# Epoch 80, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.628800
# Epoch 81, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.629600
# Epoch 82, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.631200
# Epoch 83, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.627400
# Epoch 84, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.630400
# Epoch 85, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.635000
# Epoch 86, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.627400
# Epoch 87, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.631200
# Epoch 88, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.626400
# Epoch 89, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.635200
# Epoch 90, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.631000
# Epoch 91, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.624800
# Epoch 92, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.628000
# Epoch 93, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.626200
# Epoch 94, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.621400
# Epoch 95, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.627800
# Epoch 96, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.634000
# Epoch 97, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.634600
# Epoch 98, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.623200
# Epoch 99, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.630000
# Epoch 100, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.639800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Epoch Loss:     2.2327 Validation Accuracy: 0.207000
# Epoch  1, CIFAR-10 Batch 2:  Epoch Loss:     1.8556 Validation Accuracy: 0.303000
# Epoch  1, CIFAR-10 Batch 3:  Epoch Loss:     1.5781 Validation Accuracy: 0.347600
# Epoch  1, CIFAR-10 Batch 4:  Epoch Loss:     1.5730 Validation Accuracy: 0.434000
# Epoch  1, CIFAR-10 Batch 5:  Epoch Loss:     1.4695 Validation Accuracy: 0.460000
# Epoch  2, CIFAR-10 Batch 1:  Epoch Loss:     1.4558 Validation Accuracy: 0.506400
# Epoch  2, CIFAR-10 Batch 2:  Epoch Loss:     1.2379 Validation Accuracy: 0.522600
# Epoch  2, CIFAR-10 Batch 3:  Epoch Loss:     1.0527 Validation Accuracy: 0.515800
# Epoch  2, CIFAR-10 Batch 4:  Epoch Loss:     1.0872 Validation Accuracy: 0.554600
# Epoch  2, CIFAR-10 Batch 5:  Epoch Loss:     1.1011 Validation Accuracy: 0.557200
# Epoch  3, CIFAR-10 Batch 1:  Epoch Loss:     1.0576 Validation Accuracy: 0.573200
# Epoch  3, CIFAR-10 Batch 2:  Epoch Loss:     0.9594 Validation Accuracy: 0.532200
# Epoch  3, CIFAR-10 Batch 3:  Epoch Loss:     0.7143 Validation Accuracy: 0.590400
# Epoch  3, CIFAR-10 Batch 4:  Epoch Loss:     0.8395 Validation Accuracy: 0.615000
# Epoch  3, CIFAR-10 Batch 5:  Epoch Loss:     0.7840 Validation Accuracy: 0.627800
# Epoch  4, CIFAR-10 Batch 1:  Epoch Loss:     0.7737 Validation Accuracy: 0.628000
# Epoch  4, CIFAR-10 Batch 2:  Epoch Loss:     0.5712 Validation Accuracy: 0.645800
# Epoch  4, CIFAR-10 Batch 3:  Epoch Loss:     0.4784 Validation Accuracy: 0.648600
# Epoch  4, CIFAR-10 Batch 4:  Epoch Loss:     0.5017 Validation Accuracy: 0.666400
# Epoch  4, CIFAR-10 Batch 5:  Epoch Loss:     0.4625 Validation Accuracy: 0.667800
# Epoch  5, CIFAR-10 Batch 1:  Epoch Loss:     0.4985 Validation Accuracy: 0.651200
# Epoch  5, CIFAR-10 Batch 2:  Epoch Loss:     0.3973 Validation Accuracy: 0.665200
# Epoch  5, CIFAR-10 Batch 3:  Epoch Loss:     0.3387 Validation Accuracy: 0.689800
# Epoch  5, CIFAR-10 Batch 4:  Epoch Loss:     0.4437 Validation Accuracy: 0.674200
# Epoch  5, CIFAR-10 Batch 5:  Epoch Loss:     0.3007 Validation Accuracy: 0.684200
# Epoch  6, CIFAR-10 Batch 1:  Epoch Loss:     0.3661 Validation Accuracy: 0.697600
# Epoch  6, CIFAR-10 Batch 2:  Epoch Loss:     0.2677 Validation Accuracy: 0.703600
# Epoch  6, CIFAR-10 Batch 3:  Epoch Loss:     0.2077 Validation Accuracy: 0.694800
# Epoch  6, CIFAR-10 Batch 4:  Epoch Loss:     0.2611 Validation Accuracy: 0.710600
# Epoch  6, CIFAR-10 Batch 5:  Epoch Loss:     0.2008 Validation Accuracy: 0.716600
# Epoch  7, CIFAR-10 Batch 1:  Epoch Loss:     0.2720 Validation Accuracy: 0.700600
# Epoch  7, CIFAR-10 Batch 2:  Epoch Loss:     0.1921 Validation Accuracy: 0.711400
# Epoch  7, CIFAR-10 Batch 3:  Epoch Loss:     0.1371 Validation Accuracy: 0.707600
# Epoch  7, CIFAR-10 Batch 4:  Epoch Loss:     0.2278 Validation Accuracy: 0.702800
# Epoch  7, CIFAR-10 Batch 5:  Epoch Loss:     0.1288 Validation Accuracy: 0.721000
# Epoch  8, CIFAR-10 Batch 1:  Epoch Loss:     0.1948 Validation Accuracy: 0.713000
# Epoch  8, CIFAR-10 Batch 2:  Epoch Loss:     0.1013 Validation Accuracy: 0.723800
# Epoch  8, CIFAR-10 Batch 3:  Epoch Loss:     0.1394 Validation Accuracy: 0.698400
# Epoch  8, CIFAR-10 Batch 4:  Epoch Loss:     0.1429 Validation Accuracy: 0.712800
# Epoch  8, CIFAR-10 Batch 5:  Epoch Loss:     0.1080 Validation Accuracy: 0.715600
# Epoch  9, CIFAR-10 Batch 1:  Epoch Loss:     0.1168 Validation Accuracy: 0.711200
# Epoch  9, CIFAR-10 Batch 2:  Epoch Loss:     0.0973 Validation Accuracy: 0.727400
# Epoch  9, CIFAR-10 Batch 3:  Epoch Loss:     0.0496 Validation Accuracy: 0.713200
# Epoch  9, CIFAR-10 Batch 4:  Epoch Loss:     0.0944 Validation Accuracy: 0.725400
# Epoch  9, CIFAR-10 Batch 5:  Epoch Loss:     0.0644 Validation Accuracy: 0.715200
# Epoch 10, CIFAR-10 Batch 1:  Epoch Loss:     0.0888 Validation Accuracy: 0.706600
# Epoch 10, CIFAR-10 Batch 2:  Epoch Loss:     0.0747 Validation Accuracy: 0.709400
# Epoch 10, CIFAR-10 Batch 3:  Epoch Loss:     0.0376 Validation Accuracy: 0.714200
# Epoch 10, CIFAR-10 Batch 4:  Epoch Loss:     0.0638 Validation Accuracy: 0.723400
# Epoch 10, CIFAR-10 Batch 5:  Epoch Loss:     0.0673 Validation Accuracy: 0.715400
# Epoch 11, CIFAR-10 Batch 1:  Epoch Loss:     0.0591 Validation Accuracy: 0.723600
# Epoch 11, CIFAR-10 Batch 2:  Epoch Loss:     0.0426 Validation Accuracy: 0.713600
# Epoch 11, CIFAR-10 Batch 3:  Epoch Loss:     0.0395 Validation Accuracy: 0.721800
# Epoch 11, CIFAR-10 Batch 4:  Epoch Loss:     0.0578 Validation Accuracy: 0.731000
# Epoch 11, CIFAR-10 Batch 5:  Epoch Loss:     0.0363 Validation Accuracy: 0.721200
# Epoch 12, CIFAR-10 Batch 1:  Epoch Loss:     0.0456 Validation Accuracy: 0.722600
# Epoch 12, CIFAR-10 Batch 2:  Epoch Loss:     0.0276 Validation Accuracy: 0.720200
# Epoch 12, CIFAR-10 Batch 3:  Epoch Loss:     0.0218 Validation Accuracy: 0.725800
# Epoch 12, CIFAR-10 Batch 4:  Epoch Loss:     0.0276 Validation Accuracy: 0.735400
# Epoch 12, CIFAR-10 Batch 5:  Epoch Loss:     0.0224 Validation Accuracy: 0.714600
# Epoch 13, CIFAR-10 Batch 1:  Epoch Loss:     0.0338 Validation Accuracy: 0.727600
# Epoch 13, CIFAR-10 Batch 2:  Epoch Loss:     0.0228 Validation Accuracy: 0.738200
# Epoch 13, CIFAR-10 Batch 3:  Epoch Loss:     0.0109 Validation Accuracy: 0.737000
# Epoch 13, CIFAR-10 Batch 4:  Epoch Loss:     0.0290 Validation Accuracy: 0.730000
# Epoch 13, CIFAR-10 Batch 5:  Epoch Loss:     0.0114 Validation Accuracy: 0.716800
# Epoch 14, CIFAR-10 Batch 1:  Epoch Loss:     0.0378 Validation Accuracy: 0.725600
# Epoch 14, CIFAR-10 Batch 2:  Epoch Loss:     0.0330 Validation Accuracy: 0.703600
# Epoch 14, CIFAR-10 Batch 3:  Epoch Loss:     0.0128 Validation Accuracy: 0.728000
# Epoch 14, CIFAR-10 Batch 4:  Epoch Loss:     0.0111 Validation Accuracy: 0.725800
# Epoch 14, CIFAR-10 Batch 5:  Epoch Loss:     0.0133 Validation Accuracy: 0.728400
# Epoch 15, CIFAR-10 Batch 1:  Epoch Loss:     0.0314 Validation Accuracy: 0.717600
# Epoch 15, CIFAR-10 Batch 2:  Epoch Loss:     0.0165 Validation Accuracy: 0.695400
# Epoch 15, CIFAR-10 Batch 3:  Epoch Loss:     0.0080 Validation Accuracy: 0.746800
# Epoch 15, CIFAR-10 Batch 4:  Epoch Loss:     0.0215 Validation Accuracy: 0.732400
# Epoch 15, CIFAR-10 Batch 5:  Epoch Loss:     0.0107 Validation Accuracy: 0.734600
# Epoch 16, CIFAR-10 Batch 1:  Epoch Loss:     0.0188 Validation Accuracy: 0.719400
# Epoch 16, CIFAR-10 Batch 2:  Epoch Loss:     0.0160 Validation Accuracy: 0.724200
# Epoch 16, CIFAR-10 Batch 3:  Epoch Loss:     0.0041 Validation Accuracy: 0.732000
# Epoch 16, CIFAR-10 Batch 4:  Epoch Loss:     0.0135 Validation Accuracy: 0.715200
# Epoch 16, CIFAR-10 Batch 5:  Epoch Loss:     0.0082 Validation Accuracy: 0.734400
# Epoch 17, CIFAR-10 Batch 1:  Epoch Loss:     0.0087 Validation Accuracy: 0.736000
# Epoch 17, CIFAR-10 Batch 2:  Epoch Loss:     0.0063 Validation Accuracy: 0.728400
# Epoch 17, CIFAR-10 Batch 3:  Epoch Loss:     0.0040 Validation Accuracy: 0.722600
# Epoch 17, CIFAR-10 Batch 4:  Epoch Loss:     0.0088 Validation Accuracy: 0.728800
# Epoch 17, CIFAR-10 Batch 5:  Epoch Loss:     0.0068 Validation Accuracy: 0.734800
# Epoch 18, CIFAR-10 Batch 1:  Epoch Loss:     0.0098 Validation Accuracy: 0.725400
# Epoch 18, CIFAR-10 Batch 2:  Epoch Loss:     0.0043 Validation Accuracy: 0.730800
# Epoch 18, CIFAR-10 Batch 3:  Epoch Loss:     0.0037 Validation Accuracy: 0.738600
# Epoch 18, CIFAR-10 Batch 4:  Epoch Loss:     0.0063 Validation Accuracy: 0.731600
# Epoch 18, CIFAR-10 Batch 5:  Epoch Loss:     0.0015 Validation Accuracy: 0.734400
# Epoch 19, CIFAR-10 Batch 1:  Epoch Loss:     0.0060 Validation Accuracy: 0.734000
# Epoch 19, CIFAR-10 Batch 2:  Epoch Loss:     0.0041 Validation Accuracy: 0.732200
# Epoch 19, CIFAR-10 Batch 3:  Epoch Loss:     0.0081 Validation Accuracy: 0.732600
# Epoch 19, CIFAR-10 Batch 4:  Epoch Loss:     0.0042 Validation Accuracy: 0.721400
# Epoch 19, CIFAR-10 Batch 5:  Epoch Loss:     0.0091 Validation Accuracy: 0.723800
# Epoch 20, CIFAR-10 Batch 1:  Epoch Loss:     0.0078 Validation Accuracy: 0.743200
# Epoch 20, CIFAR-10 Batch 2:  Epoch Loss:     0.0027 Validation Accuracy: 0.732400
# Epoch 20, CIFAR-10 Batch 3:  Epoch Loss:     0.0018 Validation Accuracy: 0.733400
# Epoch 20, CIFAR-10 Batch 4:  Epoch Loss:     0.0041 Validation Accuracy: 0.706200
# Epoch 20, CIFAR-10 Batch 5:  Epoch Loss:     0.0030 Validation Accuracy: 0.726800
# Epoch 21, CIFAR-10 Batch 1:  Epoch Loss:     0.0077 Validation Accuracy: 0.739200
# Epoch 21, CIFAR-10 Batch 2:  Epoch Loss:     0.0074 Validation Accuracy: 0.732600
# Epoch 21, CIFAR-10 Batch 3:  Epoch Loss:     0.0037 Validation Accuracy: 0.728800
# Epoch 21, CIFAR-10 Batch 4:  Epoch Loss:     0.0016 Validation Accuracy: 0.722000
# Epoch 21, CIFAR-10 Batch 5:  Epoch Loss:     0.0009 Validation Accuracy: 0.735200
# Epoch 22, CIFAR-10 Batch 1:  Epoch Loss:     0.0042 Validation Accuracy: 0.744000
# Epoch 22, CIFAR-10 Batch 2:  Epoch Loss:     0.0057 Validation Accuracy: 0.732400
# Epoch 22, CIFAR-10 Batch 3:  Epoch Loss:     0.0039 Validation Accuracy: 0.729000
# Epoch 22, CIFAR-10 Batch 4:  Epoch Loss:     0.0014 Validation Accuracy: 0.734600
# Epoch 22, CIFAR-10 Batch 5:  Epoch Loss:     0.0009 Validation Accuracy: 0.735400
# Epoch 23, CIFAR-10 Batch 1:  Epoch Loss:     0.0040 Validation Accuracy: 0.740000
# Epoch 23, CIFAR-10 Batch 2:  Epoch Loss:     0.0066 Validation Accuracy: 0.738400
# Epoch 23, CIFAR-10 Batch 3:  Epoch Loss:     0.0028 Validation Accuracy: 0.733200
# Epoch 23, CIFAR-10 Batch 4:  Epoch Loss:     0.0019 Validation Accuracy: 0.742000
# Epoch 23, CIFAR-10 Batch 5:  Epoch Loss:     0.0012 Validation Accuracy: 0.733000
# Epoch 24, CIFAR-10 Batch 1:  Epoch Loss:     0.0012 Validation Accuracy: 0.735200
# Epoch 24, CIFAR-10 Batch 2:  Epoch Loss:     0.0008 Validation Accuracy: 0.734000
# Epoch 24, CIFAR-10 Batch 3:  Epoch Loss:     0.0018 Validation Accuracy: 0.731400
# Epoch 24, CIFAR-10 Batch 4:  Epoch Loss:     0.0032 Validation Accuracy: 0.727400
# Epoch 24, CIFAR-10 Batch 5:  Epoch Loss:     0.0016 Validation Accuracy: 0.733200
# Epoch 25, CIFAR-10 Batch 1:  Epoch Loss:     0.0005 Validation Accuracy: 0.723600
# Epoch 25, CIFAR-10 Batch 2:  Epoch Loss:     0.0012 Validation Accuracy: 0.743400
# Epoch 25, CIFAR-10 Batch 3:  Epoch Loss:     0.0012 Validation Accuracy: 0.739600
# Epoch 25, CIFAR-10 Batch 4:  Epoch Loss:     0.0007 Validation Accuracy: 0.737400
# Epoch 25, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.736000
# Epoch 26, CIFAR-10 Batch 1:  Epoch Loss:     0.0017 Validation Accuracy: 0.727800
# Epoch 26, CIFAR-10 Batch 2:  Epoch Loss:     0.0010 Validation Accuracy: 0.745400
# Epoch 26, CIFAR-10 Batch 3:  Epoch Loss:     0.0037 Validation Accuracy: 0.743200
# Epoch 26, CIFAR-10 Batch 4:  Epoch Loss:     0.0010 Validation Accuracy: 0.740000
# Epoch 26, CIFAR-10 Batch 5:  Epoch Loss:     0.0022 Validation Accuracy: 0.733000
# Epoch 27, CIFAR-10 Batch 1:  Epoch Loss:     0.0014 Validation Accuracy: 0.734400
# Epoch 27, CIFAR-10 Batch 2:  Epoch Loss:     0.0020 Validation Accuracy: 0.749800
# Epoch 27, CIFAR-10 Batch 3:  Epoch Loss:     0.0011 Validation Accuracy: 0.735400
# Epoch 27, CIFAR-10 Batch 4:  Epoch Loss:     0.0032 Validation Accuracy: 0.744800
# Epoch 27, CIFAR-10 Batch 5:  Epoch Loss:     0.0017 Validation Accuracy: 0.738600
# Epoch 28, CIFAR-10 Batch 1:  Epoch Loss:     0.0011 Validation Accuracy: 0.741400
# Epoch 28, CIFAR-10 Batch 2:  Epoch Loss:     0.0006 Validation Accuracy: 0.740600
# Epoch 28, CIFAR-10 Batch 3:  Epoch Loss:     0.0007 Validation Accuracy: 0.741600
# Epoch 28, CIFAR-10 Batch 4:  Epoch Loss:     0.0005 Validation Accuracy: 0.741600
# Epoch 28, CIFAR-10 Batch 5:  Epoch Loss:     0.0014 Validation Accuracy: 0.740000
# Epoch 29, CIFAR-10 Batch 1:  Epoch Loss:     0.0007 Validation Accuracy: 0.731400
# Epoch 29, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.736800
# Epoch 29, CIFAR-10 Batch 3:  Epoch Loss:     0.0005 Validation Accuracy: 0.738200
# Epoch 29, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.736800
# Epoch 29, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.746000
# Epoch 30, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.734200
# Epoch 30, CIFAR-10 Batch 2:  Epoch Loss:     0.0024 Validation Accuracy: 0.730600
# Epoch 30, CIFAR-10 Batch 3:  Epoch Loss:     0.0003 Validation Accuracy: 0.735600
# Epoch 30, CIFAR-10 Batch 4:  Epoch Loss:     0.0008 Validation Accuracy: 0.735000
# Epoch 30, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.748600
# Epoch 31, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.736800
# Epoch 31, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.743600
# Epoch 31, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.738200
# Epoch 31, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.729800
# Epoch 31, CIFAR-10 Batch 5:  Epoch Loss:     0.0027 Validation Accuracy: 0.737400
# Epoch 32, CIFAR-10 Batch 1:  Epoch Loss:     0.0006 Validation Accuracy: 0.731200
# Epoch 32, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.732000
# Epoch 32, CIFAR-10 Batch 3:  Epoch Loss:     0.0003 Validation Accuracy: 0.724400
# Epoch 32, CIFAR-10 Batch 4:  Epoch Loss:     0.0047 Validation Accuracy: 0.728600
# Epoch 32, CIFAR-10 Batch 5:  Epoch Loss:     0.0008 Validation Accuracy: 0.736600
# Epoch 33, CIFAR-10 Batch 1:  Epoch Loss:     0.0007 Validation Accuracy: 0.732400
# Epoch 33, CIFAR-10 Batch 2:  Epoch Loss:     0.0004 Validation Accuracy: 0.739800
# Epoch 33, CIFAR-10 Batch 3:  Epoch Loss:     0.0006 Validation Accuracy: 0.725400
# Epoch 33, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.741200
# Epoch 33, CIFAR-10 Batch 5:  Epoch Loss:     0.0017 Validation Accuracy: 0.746600
# Epoch 34, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.742600
# Epoch 34, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.745800
# Epoch 34, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.744400
# Epoch 34, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.737600
# Epoch 34, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.747400
# Epoch 35, CIFAR-10 Batch 1:  Epoch Loss:     0.0009 Validation Accuracy: 0.732000
# Epoch 35, CIFAR-10 Batch 2:  Epoch Loss:     0.0177 Validation Accuracy: 0.748000
# Epoch 35, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.751000
# Epoch 35, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.738600
# Epoch 35, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.744800
# Epoch 36, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.738000
# Epoch 36, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.739000
# Epoch 36, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.741600
# Epoch 36, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.738400
# Epoch 36, CIFAR-10 Batch 5:  Epoch Loss:     0.0003 Validation Accuracy: 0.744600
# Epoch 37, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.744600
# Epoch 37, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.728800
# Epoch 37, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.742200
# Epoch 37, CIFAR-10 Batch 4:  Epoch Loss:     0.0012 Validation Accuracy: 0.732600
# Epoch 37, CIFAR-10 Batch 5:  Epoch Loss:     0.0003 Validation Accuracy: 0.738200
# Epoch 38, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.741600
# Epoch 38, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 38, CIFAR-10 Batch 3:  Epoch Loss:     0.0003 Validation Accuracy: 0.744800
# Epoch 38, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.735800
# Epoch 38, CIFAR-10 Batch 5:  Epoch Loss:     0.0007 Validation Accuracy: 0.742800
# Epoch 39, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.739000
# Epoch 39, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.741200
# Epoch 39, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.746000
# Epoch 39, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.732000
# Epoch 39, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.736200
# Epoch 40, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.734000
# Epoch 40, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.752800
# Epoch 40, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.747800
# Epoch 40, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.732000
# Epoch 40, CIFAR-10 Batch 5:  Epoch Loss:     0.0003 Validation Accuracy: 0.742200
# Epoch 41, CIFAR-10 Batch 1:  Epoch Loss:     0.0006 Validation Accuracy: 0.734400
# Epoch 41, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.746000
# Epoch 41, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.747200
# Epoch 41, CIFAR-10 Batch 4:  Epoch Loss:     0.0008 Validation Accuracy: 0.744600
# Epoch 41, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.731000
# Epoch 42, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.741600
# Epoch 42, CIFAR-10 Batch 2:  Epoch Loss:     0.0007 Validation Accuracy: 0.750200
# Epoch 42, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.740400
# Epoch 42, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.743000
# Epoch 42, CIFAR-10 Batch 5:  Epoch Loss:     0.0005 Validation Accuracy: 0.750800
# Epoch 43, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.739200
# Epoch 43, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 43, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.744200
# Epoch 43, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.742800
# Epoch 43, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.745600
# Epoch 44, CIFAR-10 Batch 1:  Epoch Loss:     0.0039 Validation Accuracy: 0.737200
# Epoch 44, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.741600
# Epoch 44, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.747800
# Epoch 44, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.739400
# Epoch 44, CIFAR-10 Batch 5:  Epoch Loss:     0.0003 Validation Accuracy: 0.749400
# Epoch 45, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.743400
# Epoch 45, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.746600
# Epoch 45, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.748400
# Epoch 45, CIFAR-10 Batch 4:  Epoch Loss:     0.0029 Validation Accuracy: 0.743000
# Epoch 45, CIFAR-10 Batch 5:  Epoch Loss:     0.0006 Validation Accuracy: 0.738400
# Epoch 46, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.740000
# Epoch 46, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.744400
# Epoch 46, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.743800
# Epoch 46, CIFAR-10 Batch 4:  Epoch Loss:     0.0004 Validation Accuracy: 0.747200
# Epoch 46, CIFAR-10 Batch 5:  Epoch Loss:     0.0035 Validation Accuracy: 0.744000
# Epoch 47, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.753000
# Epoch 47, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.748600
# Epoch 47, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.746800
# Epoch 47, CIFAR-10 Batch 4:  Epoch Loss:     0.0007 Validation Accuracy: 0.742600
# Epoch 47, CIFAR-10 Batch 5:  Epoch Loss:     0.0003 Validation Accuracy: 0.751000
# Epoch 48, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.734400
# Epoch 48, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.742800
# Epoch 48, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 48, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.741800
# Epoch 48, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.745400
# Epoch 49, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.746400
# Epoch 49, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.744200
# Epoch 49, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.738400
# Epoch 49, CIFAR-10 Batch 4:  Epoch Loss:     0.0014 Validation Accuracy: 0.727800
# Epoch 49, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.748400
# Epoch 50, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.746200
# Epoch 50, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.747400
# Epoch 50, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.740000
# Epoch 50, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.748600
# Epoch 50, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 51, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.746800
# Epoch 51, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.747200
# Epoch 51, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.751000
# Epoch 51, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.751200
# Epoch 51, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.745600
# Epoch 52, CIFAR-10 Batch 1:  Epoch Loss:     0.0003 Validation Accuracy: 0.745600
# Epoch 52, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.740200
# Epoch 52, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.753600
# Epoch 52, CIFAR-10 Batch 4:  Epoch Loss:     0.0038 Validation Accuracy: 0.744200
# Epoch 52, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.745000
# Epoch 53, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.749800
# Epoch 53, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.751800
# Epoch 53, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.741000
# Epoch 53, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.747000
# Epoch 53, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.752400
# Epoch 54, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.751600
# Epoch 54, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.741200
# Epoch 54, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.740600
# Epoch 54, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.745800
# Epoch 54, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.749000
# Epoch 55, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.744800
# Epoch 55, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.755000
# Epoch 55, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.738800
# Epoch 55, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.742600
# Epoch 55, CIFAR-10 Batch 5:  Epoch Loss:     0.0010 Validation Accuracy: 0.747000
# Epoch 56, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.753800
# Epoch 56, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 56, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.750400
# Epoch 56, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.738200
# Epoch 56, CIFAR-10 Batch 5:  Epoch Loss:     0.0004 Validation Accuracy: 0.739400
# Epoch 57, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.754800
# Epoch 57, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.739200
# Epoch 57, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.742400
# Epoch 57, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.747800
# Epoch 57, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.749400
# Epoch 58, CIFAR-10 Batch 1:  Epoch Loss:     0.0008 Validation Accuracy: 0.750000
# Epoch 58, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.750000
# Epoch 58, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.752400
# Epoch 58, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.743600
# Epoch 58, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.749200
# Epoch 59, CIFAR-10 Batch 1:  Epoch Loss:     0.0010 Validation Accuracy: 0.741200
# Epoch 59, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.749200
# Epoch 59, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.746000
# Epoch 59, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.749000
# Epoch 59, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.748200
# Epoch 60, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.746800
# Epoch 60, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.743800
# Epoch 60, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.747000
# Epoch 60, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.749000
# Epoch 60, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.742000
# Epoch 61, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 61, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.746600
# Epoch 61, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.741200
# Epoch 61, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.742000
# Epoch 61, CIFAR-10 Batch 5:  Epoch Loss:     0.0007 Validation Accuracy: 0.752400
# Epoch 62, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.745600
# Epoch 62, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.741800
# Epoch 62, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.740400
# Epoch 62, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.739600
# Epoch 62, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.735600
# Epoch 63, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.746200
# Epoch 63, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.739800
# Epoch 63, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.744000
# Epoch 63, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 63, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.747200
# Epoch 64, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.748000
# Epoch 64, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.752200
# Epoch 64, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.739600
# Epoch 64, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.744400
# Epoch 64, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.748000
# Epoch 65, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.739000
# Epoch 65, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.735400
# Epoch 65, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.742400
# Epoch 65, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.748400
# Epoch 65, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.750000
# Epoch 66, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.749400
# Epoch 66, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.741600
# Epoch 66, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 66, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.748400
# Epoch 66, CIFAR-10 Batch 5:  Epoch Loss:     0.0028 Validation Accuracy: 0.746800
# Epoch 67, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.747200
# Epoch 67, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.739200
# Epoch 67, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.751800
# Epoch 67, CIFAR-10 Batch 4:  Epoch Loss:     0.0009 Validation Accuracy: 0.729400
# Epoch 67, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.744400
# Epoch 68, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.744400
# Epoch 68, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.752200
# Epoch 68, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.734200
# Epoch 68, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.746000
# Epoch 68, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 69, CIFAR-10 Batch 1:  Epoch Loss:     0.0002 Validation Accuracy: 0.747000
# Epoch 69, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 69, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.746600
# Epoch 69, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.744200
# Epoch 69, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.754000
# Epoch 70, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.756200
# Epoch 70, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.751400
# Epoch 70, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.744400
# Epoch 70, CIFAR-10 Batch 4:  Epoch Loss:     0.0003 Validation Accuracy: 0.736400
# Epoch 70, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.754400
# Epoch 71, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.749800
# Epoch 71, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.743600
# Epoch 71, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 71, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.745600
# Epoch 71, CIFAR-10 Batch 5:  Epoch Loss:     0.0002 Validation Accuracy: 0.745200
# Epoch 72, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.751800
# Epoch 72, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.755600
# Epoch 72, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.753600
# Epoch 72, CIFAR-10 Batch 4:  Epoch Loss:     0.0060 Validation Accuracy: 0.748800
# Epoch 72, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.746400
# Epoch 73, CIFAR-10 Batch 1:  Epoch Loss:     0.0001 Validation Accuracy: 0.757000
# Epoch 73, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.754000
# Epoch 73, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.748400
# Epoch 73, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.745400
# Epoch 73, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.749800
# Epoch 74, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.750000
# Epoch 74, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747200
# Epoch 74, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 74, CIFAR-10 Batch 4:  Epoch Loss:     0.0004 Validation Accuracy: 0.744200
# Epoch 74, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.746800
# Epoch 75, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.744400
# Epoch 75, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.745400
# Epoch 75, CIFAR-10 Batch 3:  Epoch Loss:     0.0014 Validation Accuracy: 0.746600
# Epoch 75, CIFAR-10 Batch 4:  Epoch Loss:     0.0084 Validation Accuracy: 0.747600
# Epoch 75, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.754000
# Epoch 76, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.745600
# Epoch 76, CIFAR-10 Batch 2:  Epoch Loss:     0.0025 Validation Accuracy: 0.752200
# Epoch 76, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.755000
# Epoch 76, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.742800
# Epoch 76, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.751200
# Epoch 77, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.748000
# Epoch 77, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.743600
# Epoch 77, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.751400
# Epoch 77, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.754400
# Epoch 77, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.753800
# Epoch 78, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.753800
# Epoch 78, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.749400
# Epoch 78, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.747200
# Epoch 78, CIFAR-10 Batch 4:  Epoch Loss:     0.0366 Validation Accuracy: 0.750800
# Epoch 78, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.756800
# Epoch 79, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.753600
# Epoch 79, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 79, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.741600
# Epoch 79, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.751800
# Epoch 79, CIFAR-10 Batch 5:  Epoch Loss:     0.0012 Validation Accuracy: 0.746400
# Epoch 80, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.750400
# Epoch 80, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.754000
# Epoch 80, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.740000
# Epoch 80, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.752800
# Epoch 80, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.750000
# Epoch 81, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.759200
# Epoch 81, CIFAR-10 Batch 2:  Epoch Loss:     0.0002 Validation Accuracy: 0.746800
# Epoch 81, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.748800
# Epoch 81, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.758600
# Epoch 81, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.759000
# Epoch 82, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.759000
# Epoch 82, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.750400
# Epoch 82, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.746400
# Epoch 82, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.751200
# Epoch 82, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.745000
# Epoch 83, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.758400
# Epoch 83, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.741200
# Epoch 83, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 83, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.755000
# Epoch 83, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 84, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.751200
# Epoch 84, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747000
# Epoch 84, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.744200
# Epoch 84, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.743600
# Epoch 84, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.751600
# Epoch 85, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.748200
# Epoch 85, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.746400
# Epoch 85, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.749000
# Epoch 85, CIFAR-10 Batch 4:  Epoch Loss:     0.0006 Validation Accuracy: 0.745400
# Epoch 85, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.747200
# Epoch 86, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.749400
# Epoch 86, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.739000
# Epoch 86, CIFAR-10 Batch 3:  Epoch Loss:     0.0001 Validation Accuracy: 0.751000
# Epoch 86, CIFAR-10 Batch 4:  Epoch Loss:     0.0008 Validation Accuracy: 0.747400
# Epoch 86, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.746400
# Epoch 87, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.755000
# Epoch 87, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.751400
# Epoch 87, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.741800
# Epoch 87, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.750200
# Epoch 87, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.754600
# Epoch 88, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.754200
# Epoch 88, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.756600
# Epoch 88, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.750400
# Epoch 88, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.759000
# Epoch 88, CIFAR-10 Batch 5:  Epoch Loss:     0.0008 Validation Accuracy: 0.753200
# Epoch 89, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.755800
# Epoch 89, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.756600
# Epoch 89, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.752200
# Epoch 89, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.740600
# Epoch 89, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.748600
# Epoch 90, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.745400
# Epoch 90, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.747400
# Epoch 90, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.753000
# Epoch 90, CIFAR-10 Batch 4:  Epoch Loss:     0.0002 Validation Accuracy: 0.741800
# Epoch 90, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.746200
# Epoch 91, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 91, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.753200
# Epoch 91, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.749400
# Epoch 91, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.746400
# Epoch 91, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.751200
# Epoch 92, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.758600
# Epoch 92, CIFAR-10 Batch 2:  Epoch Loss:     0.0005 Validation Accuracy: 0.756400
# Epoch 92, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.752200
# Epoch 92, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.748600
# Epoch 92, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.752200
# Epoch 93, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.754200
# Epoch 93, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.751000
# Epoch 93, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.752600
# Epoch 93, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.745400
# Epoch 93, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.752000
# Epoch 94, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.758400
# Epoch 94, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.745200
# Epoch 94, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.734400
# Epoch 94, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.751600
# Epoch 94, CIFAR-10 Batch 5:  Epoch Loss:     0.0001 Validation Accuracy: 0.750600
# Epoch 95, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 95, CIFAR-10 Batch 2:  Epoch Loss:     0.0003 Validation Accuracy: 0.755000
# Epoch 95, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.752600
# Epoch 95, CIFAR-10 Batch 4:  Epoch Loss:     0.0001 Validation Accuracy: 0.753000
# Epoch 95, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.749800
# Epoch 96, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.761400
# Epoch 96, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 96, CIFAR-10 Batch 3:  Epoch Loss:     0.0002 Validation Accuracy: 0.755000
# Epoch 96, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.746000
# Epoch 96, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.753400
# Epoch 97, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.748800
# Epoch 97, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.754000
# Epoch 97, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 97, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.747800
# Epoch 97, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.756000
# Epoch 98, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.753600
# Epoch 98, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.761200
# Epoch 98, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.748000
# Epoch 98, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.749200
# Epoch 98, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.754200
# Epoch 99, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.758800
# Epoch 99, CIFAR-10 Batch 2:  Epoch Loss:     0.0001 Validation Accuracy: 0.763400
# Epoch 99, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.741200
# Epoch 99, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.748000
# Epoch 99, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.749000
# Epoch 100, CIFAR-10 Batch 1:  Epoch Loss:     0.0000 Validation Accuracy: 0.751600
# Epoch 100, CIFAR-10 Batch 2:  Epoch Loss:     0.0000 Validation Accuracy: 0.752200
# Epoch 100, CIFAR-10 Batch 3:  Epoch Loss:     0.0000 Validation Accuracy: 0.747600
# Epoch 100, CIFAR-10 Batch 4:  Epoch Loss:     0.0000 Validation Accuracy: 0.752000
# Epoch 100, CIFAR-10 Batch 5:  Epoch Loss:     0.0000 Validation Accuracy: 0.744600

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.729296875

# %% [raw]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
